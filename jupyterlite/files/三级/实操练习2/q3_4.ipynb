# %% [markdown]
# > ⚠️ **边界提示**：原 `.py` 文件使用了 `input()`，在浏览器 Pyodide/Jupyter 中会阻塞。
# > 转换脚本已自动把 `input()` 改写为**固定示例输入**（见下方代码），可直接 Run All。
# > 如需自定义输入，请手动修改变量后重新运行该 cell。

# %%
knowledge_base = {
    "病虫害识别": "利用计算机视觉、传感器技术和人工智能（AI）方法，自动检测和分类农作物上的病害（如真菌、细菌、病毒感染）和虫害（如昆虫、螨类等）的技术。",
    "模型优化": "可采用 Adam 优化器与学习率调度器实现模型优化。",
    "交互方式": "通过虚拟数据展示预测结果，可用于验证系统效果。",
}

# %%
def query_knowledge(keyword):
    results = []
    for key, value in knowledge_base.items():
        if keyword.lower() in key.lower() or keyword.lower() in value.lower():
            results.append(f"{key}: {value}")
    if not results:
        return "未找到相关知识，请尝试其他关键词。"
    return "\n".join(results)

# %%
if __name__ == "__main__":
    keyword = "垃圾分类"  # 已由转换脚本替换 input()，避免阻塞；可自行修改
    print("查询结果：")
    print(query_knowledge(keyword))

# %%
# === 显式调用（确保 Run All 能看到输出）===
keyword = "垃圾分类"  # 已由转换脚本替换 input()，避免阻塞；可自行修改
print("查询结果：")
print(query_knowledge(keyword))
